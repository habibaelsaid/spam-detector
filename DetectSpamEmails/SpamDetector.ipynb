# %% [markdown]
# # Detect Spam Emails

# %% [markdown]
#  ### Importing Needed Libraries

# %% [markdown]
# *in this section we will be using pandas library only*

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading Data

# %%
df = pd.read_csv("C:\MLprojs\spam.csv",encoding='latin-1' )

# %% [markdown]
# *using"encoding='latin-1'" to prevent unicodeError*

# %% [markdown]
# ### Data Shape

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.columns.tolist()
# Out:
# ['v1', 'v2', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4']

# %% [markdown]
# ### Data Exploratory

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.tail()
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN

# %%
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 5434  ham  Jesus armand really is trying to tell everybod...        NaN
# 1657  ham  S:-)if we have one good partnership going we w...        NaN
# 2797  ham  Purity of friendship between two is not about ...        NaN
# 1816  ham       Are you going to write ccna exam this week??        NaN
# 1835  ham                       * Will be september by then!        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5434        NaN        NaN
# 1657        NaN        NaN
# 2797        NaN        NaN
# 1816        NaN        NaN
# 1835        NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.describe()
# Out:
#           v1                      v2  \
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30
#
#                                                Unnamed: 2  \
# count                                                  50
# unique                                                 43
# top      bt not his girlfrnd... G o o d n i g h t . . .@"
# freq                                                    3
#
#                    Unnamed: 3 Unnamed: 4
# count                      12          6
# unique                     10          5
# top      MK17 92H. 450Ppw 16"    GNT:-)"
# freq                        2          2

# %%
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
df.isna().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
df.nunique()
# Out:
# v1               2
# v2            5169
# Unnamed: 2      43
# Unnamed: 3      10
# Unnamed: 4       5
# dtype: int64
